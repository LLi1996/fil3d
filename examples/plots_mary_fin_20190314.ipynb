# %%
import os
import pickle
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from cube_fil_finder.vis import tree_vis

# %matplotlib inline

# %%
reload(tree_vis)
# Out:
# <module 'cube_fil_finder.vis.tree_vis' from '/Users/larryli/Documents/CC/16-17/research/3d_filfind/cube_fil_finder/vis/tree_vis.py'>

# %%
fin_properties_df = pd.read_csv('../../data_out/allfiltered_mary_20190314.csv')

# %%
all_trees_dict = pickle.load(open('../../pickled_dicts/fourth_batch/all_trees_1_8.p', 'rb'))

# %%
for key in fin_properties_df['id']:
    assert key in all_trees_dict

# %%
fin_trees_dict = {k:all_trees_dict[k] for k in fin_properties_df['id']}

# %%
fig = tree_vis.vis_trees_sky_dist_names_3_panels(trees=fin_trees_dict, trees_name='',
                                                 return_fig=True, print_names=False)

# %%
fig.savefig('../../vis/fin/sky_distribution_no_names.pdf', dpi=500)

# %%
ave_mom_1_dict = {k: fin_properties_df.loc[fin_properties_df['id']==k]['moment_1_mean [km/s]'].values[0] for k in fin_trees_dict}

# %%
fig_2 = tree_vis.vis_trees_sky_dist_color_range_3_panels(fin_trees_dict,
                                                         'Average Velocity [km/s]',
                                                         ave_mom_1_dict,
                                                         'Spectral_r',
                                                         fig_size=(9,10),
                                                         return_fig=True)
# Out:
# in div

# %%
fig_2.savefig('../../vis/fin/sky_distribution_average_moment_1.pdf', dpi=500)

# %%
# Out:
# []
