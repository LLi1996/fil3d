# %%
import pickle
import numpy as np
from cube_fil_finder.util import cube_moments
from cube_fil_finder.galfa import galfa_const
from cube_fil_finder.galfa import galfa_util
from cube_fil_finder.util import moments

from astropy.io import fits

from matplotlib import pyplot as plt

# %matplotlib inline

# %%
ex_galfa_slice_path = '/Volumes/LarryExternal1/Research_2017/GALFA_slices_backup/umask_gaussian_30/GALFA_HI_W_S0955_V-050.4kms_umask.fits'

# %%
pickle_path_all_trees = '../pickled_dicts/all_sky_1_6_cut/all_sky_1_6.p'  
all_trees = pickle.load(open(pickle_path_all_trees, 'rb'))

# %%
top_cutoff_tree_ex = all_trees['2844_1029_0']

# %%
top_cutoff_tree_ex.root_v_slice
# Out:
# 1029

# %%
ex_slice = fits.getdata('/Volumes/LarryExternal1/Research_2017/GALFA_slices_backup/umask_gaussian_30/GALFA_HI_W_S1030_V0004.8kms_umask.fits')
# Out:
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]

# %%
this_plot_corners = [top_cutoff_tree_ex.root_node.corner_BL[0], top_cutoff_tree_ex.root_node.corner_TR[0],
                     top_cutoff_tree_ex.root_node.corner_BL[1], top_cutoff_tree_ex.root_node.corner_TR[1]]

# %%
focus_region = ex_slice[2210:, 9147:9461]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

ax.imshow(focus_region, origin='lower', cmap='binary')
ax.contour(top_cutoff_tree_ex.root_node.mask, colors='red')

fig.tight_layout()
fig.show()

# %%
ex_slice.shape
# Out:
# (2432, 21600)

# %%
this_plot_corners
# Out:
# [9147, 9461, 2210, 2329]
