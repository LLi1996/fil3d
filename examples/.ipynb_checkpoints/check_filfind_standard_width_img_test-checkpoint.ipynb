# %%
from astropy.io import fits
from fil_finder import FilFinder2D
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from astropy import units as u

# %%
import numpy as np

# %%
ex_slice_file = '/Volumes/LarryExternal1/Research_2017/GALFA_slices_backup/umask_gaussian_30/GALFA_HI_W_S0955_V-050.4kms_umask.fits'
data, hdr = fits.getdata(ex_slice_file, header=True)
# Out:
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]

# %%
hdr['BUNIT'] = 'k'

# %%
data.shape
# Out:
# (2432, 21600)

# %%
plt.imshow(data, origin='lower', cmap='gray')

# %%
data_cut = data[500:1000, 0:500]

# %%
plt.imshow(data_cut, origin='lower', cmap='binary')

# %%
fil = FilFinder2D(data_cut, header=hdr,
                  distance=100.*u.pc,beamwidth=10.*u.arcmin)

# %%
fil.preprocess_image(flatten_percent=95)

# %%
plt.imshow(fil.flat_img.value, origin='lower', cmap='binary')

# %%
s_w = 0.1 * u.pc
fil.create_mask(smooth_size=s_w/2,
                size_thresh=24*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
s_w = 0.2 * u.pc
fil.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
s_w = 0.3 * u.pc
fil.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
data_cut_2 = data[1000:1500, 7500:8000]

# %%
plt.imshow(data_cut_2, origin='lower', cmap='binary')

# %%
fil2 = FilFinder2D(data_cut_2, header=hdr,
                  distance=100.*u.pc,beamwidth=10.*u.arcmin)
fil2.preprocess_image(flatten_percent=95)
plt.imshow(fil2.flat_img.value, origin='lower', cmap='binary')

# %%
s_w = 0.1 * u.pc
fil2.create_mask(smooth_size=s_w/2,
                size_thresh=24*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-30cd7ffb3e2b> in <module>()
#       3                 size_thresh=24*s_w**2*np.pi,
#       4                 adapt_thresh=s_w*2,
# ----> 5                 verbose=True, border_masking=False)
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/fil_finder/filfinder2D.py in create_mask(self, glob_thresh, adapt_thresh, smooth_size, size_thresh, verbose, test_mode, regrid, border_masking, border_kwargs, fill_hole_size, use_existing_mask, save_png, output_mask_objs)
#     475             p.imshow(self.flat_img.value, interpolation='nearest',
#     476                      origin="lower", cmap='binary', vmin=vmin, vmax=vmax)
# --> 477             p.contour(self.mask, colors="r")
#     478             p.title("Mask on Flattened Image.")
#     479             if save_png:
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2851                       mplDeprecation)
#    2852     try:
# -> 2853         ret = ax.contour(*args, **kwargs)
#    2854     finally:
#    2855         ax._hold = washold
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in contour(self, *args, **kwargs)
#    5823             self.cla()
#    5824         kwargs['filled'] = False
# -> 5825         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    5826         self.autoscale_view()
#    5827         return contours
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     863
#     864         self._process_args(*args, **kwargs)
# --> 865         self._process_levels()
#     866
#     867         if self.colors is not None:
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_levels(self)
#    1197         # The following attributes are no longer needed, and
#    1198         # should be deprecated and removed to reduce confusion.
# -> 1199         self.vmin = np.amin(self.levels)
#    1200         self.vmax = np.amax(self.levels)
#    1201
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amin(a, axis, out, keepdims)
#    2370
#    2371     return _methods._amin(a, axis=axis,
# -> 2372                           out=out, **kwargs)
#    2373
#    2374
#
# /Users/larryli/anaconda/envs/py27research/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
s_w = 0.2 * u.pc
fil2.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
s_w = 0.3 * u.pc
fil2.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
ex_slice_file_2 = '/Volumes/LarryExternal1/Research_2017/GALFA_slices_backup/umask_gaussian_30/GALFA_HI_W_S1011_V-009.2kms_umask.fits'
data_2, hdr_2 = fits.getdata(ex_slice_file_2, header=True)

# %%
hdr_2['BUNIT'] = 'k'

# %%
data_cut_3 = data_2[1000:1500, 7500:8000]

# %%
fil3 = FilFinder2D(data_cut_3, header=hdr_2,
                  distance=100.*u.pc,beamwidth=10.*u.arcmin)
fil3.preprocess_image(flatten_percent=95)
plt.imshow(fil3.flat_img.value, origin='lower', cmap='binary')

# %%
s_w = 0.1 * u.pc
fil3.create_mask(smooth_size=s_w/2,
                 size_thresh=24*s_w**2*np.pi,
                 adapt_thresh=s_w*2,
                 verbose=True, border_masking=False)

# %%
s_w = 0.2 * u.pc
fil3.create_mask(smooth_size=s_w/2,
                 size_thresh=24*s_w**2*np.pi,
                 adapt_thresh=s_w*2,
                 verbose=True, border_masking=False)

# %%
s_w = 0.3 * u.pc
fil3.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
s_w = 0.4 * u.pc
fil3.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
s_w = 0.5 * u.pc
fil3.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                verbose=True, border_masking=False)

# %%
mask_objs, corners = fil3.create_mask(smooth_size=s_w/2,
                size_thresh=5*s_w**2*np.pi,
                adapt_thresh=s_w*2,
                border_masking=False, output_mask_objs=True)

# %%
corners
# Out:
# [[(189, 219), (312, 387)], [(332, 18), (439, 108)], [(359, 256), (422, 371)]]

# %%
fil3.medskel()
fil3.analyze_skeletons()

# %%
fil3.save_name
# Out:
# 'FilFinder_output'

# %%
a = []
for bs in a:
    print bs
