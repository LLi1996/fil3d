# %%
bad_keys = ['418_1050_6', '467_1074_13', '620_1013_3', '675_971_3', '684_1054_7', '791_1055_3',
            '810_1017_1', '850_993_2', '859_1000_1', '940_1015_3', '1083_1061_2', '1175_1061_0',
            '1383_1060_0', '3933_1027_0',
            '375_1057_25', '798_1012_3', '947_1049_0', '1039_1056_0', '1060_1008_0', '1259_1063_0',
            '2029_1055_0',
            '900_1066_1']

junk = ["467_1074_13","1060_1008_0","2256_1035_0",
"1383_1060_0","1259_1063_0","2381_1000_0","881_1034_4",
"845_1029_2","800_1006_4","1039_1056_0","859_1000_1",
"675_971_3","374_1022_11","1978_1028_0","620_1013_3",
"598_1043_0","798_1012_3","756_1035_4","1626_1017_0",
"465_1034_8","2923_1029_0","418_1050_6","11019_1026_0",
"1083_1061_2","1969_1030_0","1175_1061_0","2029_1055_0",
"1169_1040_1","684_1054_7","940_1015_3","900_1066_1",
"666_1021_5","1280_998_0","743_998_1","1670_985_0",
"594_1022_2","460_1020_2","559_971_0","850_993_2",
"1020_1032_2","375_1057_25","791_1055_3","947_1049_0"]

bad_trees = ['5216_1028_0','7901_955_0','6499_985_0','2431_1020_0','4753_990_0','2844_1029_0','3482_975_0',
 '11433_997_0','6932_974_0','18355_1014_0','1781_1023_0','5631_1028_0','5150_1038_0','10586_970_0','10760_983_0',
 '8776_1030_0','6720_1017_0','8738_1015_0','6012_1032_0','12141_1018_0','1995_1014_0','7611_956_0','5393_978_0',
 '6932_974_0','13922_1031_0','46955_1054_0','9905_1061_0','12603_1055_0','5191_1032_0']

# %%
len(bad_keys)
# Out:
# 22

# %%
len(junk)
# Out:
# 43

# %%
len(bad_trees)
# Out:
# 29

# %%
a = set(bad_keys + junk + bad_trees)

# %%
b = {x:0 for x in a}

# %%
for k in bad_keys + junk + bad_trees:
    b[k] += 1

# %%
b
# Out:
# {'1020_1032_2': 1,
#  '1039_1056_0': 2,
#  '10586_970_0': 1,
#  '1060_1008_0': 2,
#  '10760_983_0': 1,
#  '1083_1061_2': 2,
#  '11019_1026_0': 1,
#  '11433_997_0': 1,
#  '1169_1040_1': 1,
#  '1175_1061_0': 2,
#  '12141_1018_0': 1,
#  '1259_1063_0': 2,
#  '12603_1055_0': 1,
#  '1280_998_0': 1,
#  '1383_1060_0': 2,
#  '13922_1031_0': 1,
#  '1626_1017_0': 1,
#  '1670_985_0': 1,
#  '1781_1023_0': 1,
#  '18355_1014_0': 1,
#  '1969_1030_0': 1,
#  '1978_1028_0': 1,
#  '1995_1014_0': 1,
#  '2029_1055_0': 2,
#  '2256_1035_0': 1,
#  '2381_1000_0': 1,
#  '2431_1020_0': 1,
#  '2844_1029_0': 1,
#  '2923_1029_0': 1,
#  '3482_975_0': 1,
#  '374_1022_11': 1,
#  '375_1057_25': 2,
#  '3933_1027_0': 1,
#  '418_1050_6': 2,
#  '460_1020_2': 1,
#  '465_1034_8': 1,
#  '467_1074_13': 2,
#  '46955_1054_0': 1,
#  '4753_990_0': 1,
#  '5150_1038_0': 1,
#  '5191_1032_0': 1,
#  '5216_1028_0': 1,
#  '5393_978_0': 1,
#  '559_971_0': 1,
#  '5631_1028_0': 1,
#  '594_1022_2': 1,
#  '598_1043_0': 1,
# ...
